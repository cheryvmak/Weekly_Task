# %%
# Sample document about Python programming
sample_document = """
Python is a high-level, interpreted programming language known for its simplicity and readability. 
It was created by Guido van Rossum and first released in 1991. Python supports multiple programming 
paradigms including procedural, object-oriented, and functional programming.

One of Python's key strengths is its extensive standard library, which provides tools for many common 
programming tasks. The language emphasizes code readability with its use of significant indentation. 
Python's syntax allows programmers to express concepts in fewer lines of code compared to languages 
like C++ or Java.

Python is widely used in web development, data science, artificial intelligence, scientific computing, 
and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for 
data analysis, and TensorFlow and PyTorch for machine learning.

The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's 
capabilities. Installation is simple using pip, Python's package installer. The active community contributes 
to a rich ecosystem of libraries and frameworks.

Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly nature 
makes it ideal for education, while its powerful features support professional software development and research.
"""

print(f"Document length: {len(sample_document)} characters")
print(f"Document length: {len(sample_document.split())} words")
print(f"\nFirst 200 characters:\n{sample_document[:200]}...")
# Out:
# Document length: 1367 characters
# Document length: 187 words
#
# First 200 characters:
#
# Python is a high-level, interpreted programming language known for its simplicity and readability.
# It was created by Guido van Rossum and first released in 1991. Python supports multiple programming...

# %%
def chunk_by_characters(text, chunk_size=200, overlap=50):
    """
    Split text into chunks of specified character length.
    
    Args:
        text: The text to chunk
        chunk_size: Number of characters per chunk
        overlap: Number of characters to overlap between chunks
    
    Returns:
        List of text chunks
    """
    chunks = []
    start = 0
    
    while start < len(text):
        # Get chunk from start to start + chunk_size
        end = start + chunk_size
        chunk = text[start:end]
        chunks.append(chunk)
        
        # Move start position (with overlap)
        start += chunk_size - overlap
    
    return chunks

# Test it
chunks = chunk_by_characters(sample_document, chunk_size=200, overlap=50)

print(f"Number of chunks: {len(chunks)}\n")
for i, chunk in enumerate(chunks[:3], 1):  # Show first 3 chunks
    print(f"Chunk {i} ({len(chunk)} chars):")
    print(chunk)
    print("-" * 80)
# Out:
# Number of chunks: 10
#
# Chunk 1 (200 chars):
#
# Python is a high-level, interpreted programming language known for its simplicity and readability.
# It was created by Guido van Rossum and first released in 1991. Python supports multiple programming
# --------------------------------------------------------------------------------
# Chunk 2 (200 chars):
# ased in 1991. Python supports multiple programming
# paradigms including procedural, object-oriented, and functional programming.
#
# One of Python's key strengths is its extensive standard library, which
# --------------------------------------------------------------------------------
# Chunk 3 (200 chars):
# strengths is its extensive standard library, which provides tools for many common
# programming tasks. The language emphasizes code readability with its use of significant indentation.
# Python's syntax
# --------------------------------------------------------------------------------

# %%
chunks = []
start = 0
text= """
Python is a high-level, interpreted programming language known for its simplicity and readability. 
It was created by Guido van Rossum and first released in 1991. Python supports multiple programming 
paradigms including procedural, object-oriented, and functional programming.

One of Python's key strengths is its extensive standard library, which provides tools for many common 
programming tasks. The language emphasizes code readability with its use of significant indentation. 
Python's syntax allows programmers to express concepts in fewer lines of code compared to languages 
like C++ or Java.

Python is widely used in web development, data science, artificial intelligence, scientific computing, 
and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for 
data analysis, and TensorFlow and PyTorch for machine learning.

The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's 
capabilities. Installation is simple using pip, Python's package installer. The active community contributes 
to a rich ecosystem of libraries and frameworks.

Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly nature 
makes it ideal for education, while its powerful features support professional software development and research.
"""

chunk_size=200
overlap=50

while start < len(text):
        # Get chunk from start to start + chunk_size
        end = start + chunk_size
        print(f"start:{start} end:{end}")
        chunk = text[start:end]
        print(f"chunk:{chunk}\n")
        chunks.append(chunk)
        print(f"Appended chunk of length {len(chunk)}")
        print(chunks)

        
        # Move start position (with overlap)
        start += chunk_size - overlap
        print(chunks)
# Out:
# start:0 end:200
# chunk:
# Python is a high-level, interpreted programming language known for its simplicity and readability.
# It was created by Guido van Rossum and first released in 1991. Python supports multiple programming
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming']
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming']
# start:150 end:350
# chunk:ased in 1991. Python supports multiple programming
# paradigms including procedural, object-oriented, and functional programming.
#
# One of Python's key strengths is its extensive standard library, which
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which"]
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which"]
# start:300 end:500
# chunk:strengths is its extensive standard library, which provides tools for many common
# programming tasks. The language emphasizes code readability with its use of significant indentation.
# Python's syntax
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax"]
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax"]
# start:450 end:650
# chunk:s use of significant indentation.
# Python's syntax allows programmers to express concepts in fewer lines of code compared to languages
# like C++ or Java.
#
# Python is widely used in web development, dat
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat"]
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat"]
# start:600 end:800
# chunk:va.
#
# Python is widely used in web development, data science, artificial intelligence, scientific computing,
# and automation. Popular frameworks include Django and Flask for web development, NumPy and
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ']
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ']
# start:750 end:950
# chunk:e Django and Flask for web development, NumPy and Pandas for
# data analysis, and TensorFlow and PyTorch for machine learning.
#
# The Python Package Index (PyPI) hosts hundreds of thousands of third-part
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part']
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part']
# start:900 end:1100
# chunk:x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's
# capabilities. Installation is simple using pip, Python's package installer. The active community contributes
# to a ri
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri"]
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri"]
# start:1050 end:1250
# chunk:staller. The active community contributes
# to a rich ecosystem of libraries and frameworks.
#
# Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur
#
# Appended chunk of length 200
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri", 'staller. The active community contributes \nto a rich ecosystem of libraries and frameworks.\n\nPython continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur']
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri", 'staller. The active community contributes \nto a rich ecosystem of libraries and frameworks.\n\nPython continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur']
# start:1200 end:1400
# chunk:g languages worldwide. Its beginner-friendly nature
# makes it ideal for education, while its powerful features support professional software development and research.
#
#
# Appended chunk of length 167
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri", 'staller. The active community contributes \nto a rich ecosystem of libraries and frameworks.\n\nPython continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur', 'g languages worldwide. Its beginner-friendly nature \nmakes it ideal for education, while its powerful features support professional software development and research.\n']
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri", 'staller. The active community contributes \nto a rich ecosystem of libraries and frameworks.\n\nPython continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur', 'g languages worldwide. Its beginner-friendly nature \nmakes it ideal for education, while its powerful features support professional software development and research.\n']
# start:1350 end:1550
# chunk:nt and research.
#
#
# Appended chunk of length 17
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri", 'staller. The active community contributes \nto a rich ecosystem of libraries and frameworks.\n\nPython continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur', 'g languages worldwide. Its beginner-friendly nature \nmakes it ideal for education, while its powerful features support professional software development and research.\n', 'nt and research.\n']
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability. \nIt was created by Guido van Rossum and first released in 1991. Python supports multiple programming', "ased in 1991. Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.\n\nOne of Python's key strengths is its extensive standard library, which", "strengths is its extensive standard library, which provides tools for many common \nprogramming tasks. The language emphasizes code readability with its use of significant indentation. \nPython's syntax", "s use of significant indentation. \nPython's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.\n\nPython is widely used in web development, dat", 'va.\n\nPython is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation. Popular frameworks include Django and Flask for web development, NumPy and ', 'e Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.\n\nThe Python Package Index (PyPI) hosts hundreds of thousands of third-part', "x (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities. Installation is simple using pip, Python's package installer. The active community contributes \nto a ri", 'staller. The active community contributes \nto a rich ecosystem of libraries and frameworks.\n\nPython continues to be one of the most popular programming languages worldwide. Its beginner-friendly natur', 'g languages worldwide. Its beginner-friendly nature \nmakes it ideal for education, while its powerful features support professional software development and research.\n', 'nt and research.\n']

# %%
chunks = []
start = 0
text= """
Python is a high-level, interpreted programming language known for its simplicity and readability. 
It was created by Guido van Rossum and first released in 1991. Python supports multiple programming 
paradigms including procedural, object-oriented, and functional programming.

One of Python's key strengths is its extensive standard library, which provides tools for many common 
programming tasks. The language emphasizes code readability with its use of significant indentation. 
Python's syntax allows programmers to express concepts in fewer lines of code compared to languages 
like C++ or Java.

Python is widely used in web development, data science, artificial intelligence, scientific computing, 
and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for 
data analysis, and TensorFlow and PyTorch for machine learning.

The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's 
capabilities. Installation is simple using pip, Python's package installer. The active community contributes 
to a rich ecosystem of libraries and frameworks.

Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly nature 
makes it ideal for education, while its powerful features support professional software development and research.
"""
words = text.split()
chunk_size=50
overlap=10

while start < len(words):
        # Get chunk from start to start + chunk_size
        end = start + chunk_size
        print(f"start:{start} end:{end}")
        chunk_words = words[start:end]
        print(f"chunk:{chunk}\n")
        chunk = ' '.join(chunk_words)
        chunks.append(chunk)
        print(f"Appended chunk of length {len(chunk)}")
        print(chunks)

        
        # Move start position (with overlap)
        start += chunk_size - overlap
        print(chunks)
# Out:
# start:0 end:50
# chunk:The active community contributes
# to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly nature
# makes it ideal for education, while its powerful features support professional software development and research.
#
# Appended chunk of length 365
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for"]
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for"]
# start:40 end:90
# chunk:Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for
#
# Appended chunk of length 329
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web"]
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web"]
# start:80 end:130
# chunk:strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web
#
# Appended chunk of length 346
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web", 'like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands']
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web", 'like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands']
# start:120 end:170
# chunk:like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands
#
# Appended chunk of length 356
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web", 'like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands', "learning. The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's capabilities. Installation is simple using pip, Python's package installer. The active community contributes to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its"]
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web", 'like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands', "learning. The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's capabilities. Installation is simple using pip, Python's package installer. The active community contributes to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its"]
# start:160 end:210
# chunk:learning. The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's capabilities. Installation is simple using pip, Python's package installer. The active community contributes to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its
#
# Appended chunk of length 202
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web", 'like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands', "learning. The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's capabilities. Installation is simple using pip, Python's package installer. The active community contributes to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its", 'be one of the most popular programming languages worldwide. Its beginner-friendly nature makes it ideal for education, while its powerful features support professional software development and research.']
# ["Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for", "strengths is its extensive standard library, which provides tools for many common programming tasks. The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java. Python is widely used in web", 'like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing, and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands', "learning. The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's capabilities. Installation is simple using pip, Python's package installer. The active community contributes to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its", 'be one of the most popular programming languages worldwide. Its beginner-friendly nature makes it ideal for education, while its powerful features support professional software development and research.']

# %%
import re
text= """
Python is a high-level, interpreted programming language known for its simplicity and readability. 
It was created by Guido van Rossum and first released in 1991. Python supports multiple programming 
paradigms including procedural, object-oriented, and functional programming.

One of Python's key strengths is its extensive standard library, which provides tools for many common 
programming tasks. The language emphasizes code readability with its use of significant indentation. 
Python's syntax allows programmers to express concepts in fewer lines of code compared to languages 
like C++ or Java.

Python is widely used in web development, data science, artificial intelligence, scientific computing, 
and automation. Popular frameworks include Django and Flask for web development, NumPy and Pandas for 
data analysis, and TensorFlow and PyTorch for machine learning.

The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's 
capabilities. Installation is simple using pip, Python's package installer. The active community contributes 
to a rich ecosystem of libraries and frameworks.

Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly nature 
makes it ideal for education, while its powerful features support professional software development and research.
"""
sentences = re.split(r'(?<=[.!?])\s+', text)
print(sentences)
print(len(sentences))
# Out:
# ['\nPython is a high-level, interpreted programming language known for its simplicity and readability.', 'It was created by Guido van Rossum and first released in 1991.', 'Python supports multiple programming \nparadigms including procedural, object-oriented, and functional programming.', "One of Python's key strengths is its extensive standard library, which provides tools for many common \nprogramming tasks.", 'The language emphasizes code readability with its use of significant indentation.', "Python's syntax allows programmers to express concepts in fewer lines of code compared to languages \nlike C++ or Java.", 'Python is widely used in web development, data science, artificial intelligence, scientific computing, \nand automation.', 'Popular frameworks include Django and Flask for web development, NumPy and Pandas for \ndata analysis, and TensorFlow and PyTorch for machine learning.', "The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's \ncapabilities.", "Installation is simple using pip, Python's package installer.", 'The active community contributes \nto a rich ecosystem of libraries and frameworks.', 'Python continues to be one of the most popular programming languages worldwide.', 'Its beginner-friendly nature \nmakes it ideal for education, while its powerful features support professional software development and research.', '']
# 14

# %%
import re
sentences = re.split(r'(?<=[.!?])\s+', text)
    
chunks = []
current_chunk = ""
max_chunk_size = 400
    
for sentence in sentences:
        # Check if adding this sentence would exceed max size
        if len(current_chunk) + len(sentence) > max_chunk_size and current_chunk:
            # Save current chunk and start new one
            chunks.append(current_chunk.strip())
            current_chunk = sentence
        else:
            # Add sentence to current chunk
            current_chunk += " " + sentence if current_chunk else sentence
            print(f"start:{len(chunks)} end:{len(current_chunk)}")
    # Don't forget the last chunk
if current_chunk:
        chunks.append(current_chunk.strip())
#print(chunks)
print(f"Number of chunks: {len(chunks)}\n")
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i} ({len(chunk)} chars):")
    print(chunk)
    print("-" * 80)
# Out:
# start:0 end:99
# start:0 end:162
# start:0 end:277
# start:0 end:399
# start:1 end:200
# start:1 end:320
# start:2 end:270
# start:2 end:332
# start:3 end:162
# start:3 end:306
# start:3 end:307
# Number of chunks: 4
#
# Chunk 1 (398 chars):
# Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming
# paradigms including procedural, object-oriented, and functional programming. One of Python's key strengths is its extensive standard library, which provides tools for many common
# programming tasks.
# --------------------------------------------------------------------------------
# Chunk 2 (320 chars):
# The language emphasizes code readability with its use of significant indentation. Python's syntax allows programmers to express concepts in fewer lines of code compared to languages
# like C++ or Java. Python is widely used in web development, data science, artificial intelligence, scientific computing,
# and automation.
# --------------------------------------------------------------------------------
# Chunk 3 (332 chars):
# Popular frameworks include Django and Flask for web development, NumPy and Pandas for
# data analysis, and TensorFlow and PyTorch for machine learning. The Python Package Index (PyPI) hosts hundreds of thousands of third-party packages that extend Python's
# capabilities. Installation is simple using pip, Python's package installer.
# --------------------------------------------------------------------------------
# Chunk 4 (306 chars):
# The active community contributes
# to a rich ecosystem of libraries and frameworks. Python continues to be one of the most popular programming languages worldwide. Its beginner-friendly nature
# makes it ideal for education, while its powerful features support professional software development and research.
# --------------------------------------------------------------------------------

# %% [markdown]
# **Document A: FAQ**
# ```
# Q: What is the return policy?
# A: Items can be returned within 30 days of purchase with original receipt.
#
# Q: Do you offer international shipping?
# A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.
#
# Q: How do I track my order?
# A: Use the tracking number sent to your email after shipment.
# ```

# %%
Document_A = """
Q: What is the return policy?
A: Items can be returned within 30 days of purchase with original receipt.

Q: Do you offer international shipping?
A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.

Q: How do I track my order?
A: Use the tracking number sent to your email after shipment.
"""

print(f"Document length: {len(Document_A)} characters")
print(f"Document length: {len(Document_A.split())} words")
sentences = re.split(r'(?<=[.!?])\s+', Document_A)
print(f"Document length: {len(sentences)} sentences")

print(f"\nFirst 300 characters:\n{Document_A[:300]}...")
# Out:
# Document length: 319 characters
# Document length: 57 words
# Document length: 8 sentences
#
# First 300 characters:
#
# Q: What is the return policy?
# A: Items can be returned within 30 days of purchase with original receipt.
#
# Q: Do you offer international shipping?
# A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.
#
# Q: How do I track my order?
# A: Use the tracking number sent to your ema...

# %%
def chunk_faq(document):
    chunks = []
    blocks = document.strip().split("\n\n")  # split FAQ blocks

    for block in blocks:
        lines = block.strip().split("\n")

        if len(lines) >= 2:
            question = lines[0].strip()  # keep full Q line
            answer = " ".join(lines[1:]).strip()  # merge multi-line answers

            chunks.append(f"{question}\n{answer}")

    return chunks

chunks = chunk_faq(Document_A)
print(f"Number of chunks: {len(chunks)}\n")
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i} ({len(chunk)} chars):")
    print(chunk)
    print("-" * 80)
# Out:
# Number of chunks: 3
#
# Chunk 1 (104 chars):
# Q: What is the return policy?
# A: Items can be returned within 30 days of purchase with original receipt.
# --------------------------------------------------------------------------------
# Chunk 2 (120 chars):
# Q: Do you offer international shipping?
# A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.
# --------------------------------------------------------------------------------
# Chunk 3 (89 chars):
# Q: How do I track my order?
# A: Use the tracking number sent to your email after shipment.
# --------------------------------------------------------------------------------

# %%
blocks = Document_A.strip().split("\n\n") 
print(blocks)
for block in blocks:
        lines = block.strip().split("\n")
        print(lines)

if len(lines) >= 2:
            question = lines[0].strip() 
            print(f"Question: {question}")
            answer = " ".join(lines[1:]).strip()
            print(f"Answer: {answer}")
# Out:
# ['Q: What is the return policy?\nA: Items can be returned within 30 days of purchase with original receipt.', 'Q: Do you offer international shipping?\nA: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.', 'Q: How do I track my order?\nA: Use the tracking number sent to your email after shipment.']
# ['Q: What is the return policy?', 'A: Items can be returned within 30 days of purchase with original receipt.']
# ['Q: Do you offer international shipping?', 'A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.']
# ['Q: How do I track my order?', 'A: Use the tracking number sent to your email after shipment.']
# Question: Q: How do I track my order?
# Answer: A: Use the tracking number sent to your email after shipment.
