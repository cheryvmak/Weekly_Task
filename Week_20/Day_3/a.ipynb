# %%
import os
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    print("warning: OPENAI_API_KEY not found. Set it in a .env file")

else:
    print("API KEY loaded successfully.")
